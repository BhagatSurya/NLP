# %%
import json
import tensorflow as tf
import numpy as np
import urllib
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
import urllib


def solution_model():
    url = 'https://storage.googleapis.com/download.tensorflow.org/data/sarcasm.json'
    urllib.request.urlretrieve(url, 'sarcasm.json')
    import json
    import tensorflow as tf

    from tensorflow.keras.preprocessing.text import Tokenizer
    from tensorflow.keras.preprocessing.sequence import pad_sequences

    # DO NOT CHANGE THIS CODE OR THE TESTS MAY NOT WORK
    vocab_size = 1000
    embedding_dim = 16
    max_length = 120
    trunc_type='post'
    padding_type='post'
    oov_tok = "<OOV>"
    training_size = 20000
    with open("sarcasm.json", 'r') as f:
        datastore = json.load(f)

    sentences = []
    labels = []

    for item in datastore:
        sentences.append(item['headline'])
        labels.append(item['is_sarcastic'])

    # Download pretrained TensorFlow Hub USE
    import tensorflow_hub as hub
    tf_hub_embedding_layer = hub.KerasLayer("https://tfhub.dev/google/universal-sentence-encoder/4",
                                            trainable=False,
                                            name="universal_sentence_encoder")

    training_sentences = sentences[0:training_size]
    testing_sentences = sentences[training_size:]
    training_labels = labels[0:training_size]
    testing_labels = labels[training_size:]
    # YOUR CODE HERE

    tokenizer = Tokenizer(num_words=vocab_size, oov_token=oov_tok)
    tokenizer.fit_on_texts(training_sentences)

    word_index = tokenizer.word_index

    training_sequences = tokenizer.texts_to_sequences(training_sentences)
    training_padded = pad_sequences(training_sequences, maxlen=max_length, padding=padding_type, truncating=trunc_type)

    testing_sequences = tokenizer.texts_to_sequences(testing_sentences)
    testing_padded = pad_sequences(testing_sequences, maxlen=max_length, padding=padding_type, truncating=trunc_type)

    # Need this block to get it to work with TensorFlow 2.x
    import numpy as np
    training_padded = np.array(training_padded)
    training_labels = np.array(training_labels)
    testing_padded = np.array(testing_padded)
    testing_labels = np.array(testing_labels)

    from tensorflow.keras import layers

    model = tf.keras.Sequential([
        tf.keras.layers.Embedding(input_dim=max_length,  # set input shape
                                  output_dim=128,  # set size of embedding vector
                                  embeddings_initializer="uniform",  # default, intialize randomly
                                  input_length=max_length,  # how long is each input
                                  name="embedding_1"),
        tf.keras.layers.LSTM(128, activation="relu", return_sequences=True),
        tf.keras.layers.GlobalAveragePooling1D(),
        tf.keras.layers.Dense(3, activation='relu'),
    # YOUR CODE HERE. KEEP THIS OUTPUT LAYER INTACT OR TESTS MAY FAIL
        tf.keras.layers.Dense(1, activation='sigmoid')
    ])

    model.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])
    num_epochs = 30
    from sklearn.model_selection import KFold

    n_split=3
    for train_index,test_index in KFold(n_split).split(training_padded):
       x_train,x_test=training_padded[train_index],training_padded[test_index]
       y_train,y_test=training_labels[train_index],training_labels[test_index]
       history = model.fit(training_padded, training_labels, epochs=num_epochs, validation_data=(testing_padded, testing_labels), verbose=2)
    return model



# Note that you'll need to save your model as a .h5 like this.
# When you press the Submit and Test button, your saved .h5 model will
# be sent to the testing infrastructure for scoring
# and the score will be returned to you.
if __name__ == '__main__':
    model = solution_model()
    model.save("mymodel.h5")
# Out:
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Epoch 1/30
# 625/625 - 107s - loss: nan - accuracy: 0.5603 - val_loss: nan - val_accuracy: 0.5633 - 107s/epoch - 172ms/step
# Epoch 2/30
# 625/625 - 105s - loss: nan - accuracy: 0.5603 - val_loss: nan - val_accuracy: 0.5633 - 105s/epoch - 169ms/step
# Epoch 3/30
# 625/625 - 100s - loss: nan - accuracy: 0.5603 - val_loss: nan - val_accuracy: 0.5633 - 100s/epoch - 160ms/step
# Epoch 4/30
# 625/625 - 100s - loss: nan - accuracy: 0.5603 - val_loss: nan - val_accuracy: 0.5633 - 100s/epoch - 159ms/step
# Epoch 5/30
# 625/625 - 102s - loss: nan - accuracy: 0.5603 - val_loss: nan - val_accuracy: 0.5633 - 102s/epoch - 164ms/step
# Epoch 6/30
# 625/625 - 100s - loss: nan - accuracy: 0.5603 - val_loss: nan - val_accuracy: 0.5633 - 100s/epoch - 160ms/step
# Epoch 7/30
# 625/625 - 100s - loss: nan - accuracy: 0.5603 - val_loss: nan - val_accuracy: 0.5633 - 100s/epoch - 160ms/step
# Epoch 8/30
# 625/625 - 109s - loss: nan - accuracy: 0.5603 - val_loss: nan - val_accuracy: 0.5633 - 109s/epoch - 174ms/step
# Epoch 9/30
# 625/625 - 108s - loss: nan - accuracy: 0.5603 - val_loss: nan - val_accuracy: 0.5633 - 108s/epoch - 173ms/step
# Epoch 10/30
# 625/625 - 106s - loss: nan - accuracy: 0.5603 - val_loss: nan - val_accuracy: 0.5633 - 106s/epoch - 170ms/step
# Epoch 11/30
# 625/625 - 106s - loss: nan - accuracy: 0.5603 - val_loss: nan - val_accuracy: 0.5633 - 106s/epoch - 170ms/step
# Epoch 12/30
# 625/625 - 107s - loss: nan - accuracy: 0.5603 - val_loss: nan - val_accuracy: 0.5633 - 107s/epoch - 171ms/step
# Epoch 13/30
# 625/625 - 107s - loss: nan - accuracy: 0.5603 - val_loss: nan - val_accuracy: 0.5633 - 107s/epoch - 171ms/step
# Epoch 14/30
# 625/625 - 107s - loss: nan - accuracy: 0.5603 - val_loss: nan - val_accuracy: 0.5633 - 107s/epoch - 172ms/step
# Epoch 15/30
# 625/625 - 106s - loss: nan - accuracy: 0.5603 - val_loss: nan - val_accuracy: 0.5633 - 106s/epoch - 169ms/step
# Epoch 16/30
# 625/625 - 108s - loss: nan - accuracy: 0.5603 - val_loss: nan - val_accuracy: 0.5633 - 108s/epoch - 173ms/step
# Epoch 17/30
# 625/625 - 108s - loss: nan - accuracy: 0.5603 - val_loss: nan - val_accuracy: 0.5633 - 108s/epoch - 172ms/step
# Epoch 18/30
# 625/625 - 110s - loss: nan - accuracy: 0.5603 - val_loss: nan - val_accuracy: 0.5633 - 110s/epoch - 176ms/step
# Epoch 19/30
# 625/625 - 112s - loss: nan - accuracy: 0.5603 - val_loss: nan - val_accuracy: 0.5633 - 112s/epoch - 179ms/step
# Epoch 20/30
# 625/625 - 110s - loss: nan - accuracy: 0.5603 - val_loss: nan - val_accuracy: 0.5633 - 110s/epoch - 176ms/step
# Epoch 21/30
# 625/625 - 101s - loss: nan - accuracy: 0.5603 - val_loss: nan - val_accuracy: 0.5633 - 101s/epoch - 162ms/step
# Epoch 22/30
# 625/625 - 97s - loss: nan - accuracy: 0.5603 - val_loss: nan - val_accuracy: 0.5633 - 97s/epoch - 155ms/step
# Epoch 23/30
# 625/625 - 104s - loss: nan - accuracy: 0.5603 - val_loss: nan - val_accuracy: 0.5633 - 104s/epoch - 166ms/step
# Epoch 24/30
# 625/625 - 102s - loss: nan - accuracy: 0.5603 - val_loss: nan - val_accuracy: 0.5633 - 102s/epoch - 164ms/step
# Epoch 25/30
# 625/625 - 105s - loss: nan - accuracy: 0.5603 - val_loss: nan - val_accuracy: 0.5633 - 105s/epoch - 169ms/step
# Epoch 26/30
# 625/625 - 101s - loss: nan - accuracy: 0.5603 - val_loss: nan - val_accuracy: 0.5633 - 101s/epoch - 161ms/step
# Epoch 27/30
# 625/625 - 111s - loss: nan - accuracy: 0.5603 - val_loss: nan - val_accuracy: 0.5633 - 111s/epoch - 177ms/step
# Epoch 28/30
# 625/625 - 108s - loss: nan - accuracy: 0.5603 - val_loss: nan - val_accuracy: 0.5633 - 108s/epoch - 173ms/step
# Epoch 29/30
# 625/625 - 114s - loss: nan - accuracy: 0.5603 - val_loss: nan - val_accuracy: 0.5633 - 114s/epoch - 183ms/step
# Epoch 30/30
# 625/625 - 111s - loss: nan - accuracy: 0.5603 - val_loss: nan - val_accuracy: 0.5633 - 111s/epoch - 177ms/step
# Epoch 1/30
# 625/625 - 112s - loss: nan - accuracy: 0.5603 - val_loss: nan - val_accuracy: 0.5633 - 112s/epoch - 178ms/step
# Epoch 2/30
# 625/625 - 110s - loss: nan - accuracy: 0.5603 - val_loss: nan - val_accuracy: 0.5633 - 110s/epoch - 176ms/step
# Epoch 3/30
# 625/625 - 106s - loss: nan - accuracy: 0.5603 - val_loss: nan - val_accuracy: 0.5633 - 106s/epoch - 169ms/step
# Epoch 4/30
# 625/625 - 107s - loss: nan - accuracy: 0.5603 - val_loss: nan - val_accuracy: 0.5633 - 107s/epoch - 171ms/step
# Epoch 5/30
# 625/625 - 107s - loss: nan - accuracy: 0.5603 - val_loss: nan - val_accuracy: 0.5633 - 107s/epoch - 170ms/step
# Epoch 6/30
# 625/625 - 106s - loss: nan - accuracy: 0.5603 - val_loss: nan - val_accuracy: 0.5633 - 106s/epoch - 170ms/step
# Epoch 7/30
# 625/625 - 106s - loss: nan - accuracy: 0.5603 - val_loss: nan - val_accuracy: 0.5633 - 106s/epoch - 170ms/step
# Epoch 8/30
# 625/625 - 105s - loss: nan - accuracy: 0.5603 - val_loss: nan - val_accuracy: 0.5633 - 105s/epoch - 168ms/step
# Epoch 9/30
# 625/625 - 100s - loss: nan - accuracy: 0.5603 - val_loss: nan - val_accuracy: 0.5633 - 100s/epoch - 161ms/step
# Epoch 10/30
# 625/625 - 110s - loss: nan - accuracy: 0.5603 - val_loss: nan - val_accuracy: 0.5633 - 110s/epoch - 176ms/step
# Epoch 11/30
# 625/625 - 113s - loss: nan - accuracy: 0.5603 - val_loss: nan - val_accuracy: 0.5633 - 113s/epoch - 181ms/step
# Epoch 12/30
# 625/625 - 112s - loss: nan - accuracy: 0.5603 - val_loss: nan - val_accuracy: 0.5633 - 112s/epoch - 179ms/step
# Epoch 13/30
# 625/625 - 112s - loss: nan - accuracy: 0.5603 - val_loss: nan - val_accuracy: 0.5633 - 112s/epoch - 180ms/step
# Epoch 14/30
# 625/625 - 112s - loss: nan - accuracy: 0.5603 - val_loss: nan - val_accuracy: 0.5633 - 112s/epoch - 179ms/step
# Epoch 15/30
# 625/625 - 114s - loss: nan - accuracy: 0.5603 - val_loss: nan - val_accuracy: 0.5633 - 114s/epoch - 182ms/step
# Epoch 16/30
# 625/625 - 114s - loss: nan - accuracy: 0.5603 - val_loss: nan - val_accuracy: 0.5633 - 114s/epoch - 182ms/step
# Epoch 17/30
# 625/625 - 110s - loss: nan - accuracy: 0.5603 - val_loss: nan - val_accuracy: 0.5633 - 110s/epoch - 177ms/step
# Epoch 18/30
# 625/625 - 112s - loss: nan - accuracy: 0.5603 - val_loss: nan - val_accuracy: 0.5633 - 112s/epoch - 179ms/step
# Epoch 19/30
# 625/625 - 112s - loss: nan - accuracy: 0.5603 - val_loss: nan - val_accuracy: 0.5633 - 112s/epoch - 180ms/step
# Epoch 20/30
# 625/625 - 112s - loss: nan - accuracy: 0.5603 - val_loss: nan - val_accuracy: 0.5633 - 112s/epoch - 178ms/step
# Epoch 21/30
# 625/625 - 113s - loss: nan - accuracy: 0.5603 - val_loss: nan - val_accuracy: 0.5633 - 113s/epoch - 180ms/step
# Epoch 22/30
# 625/625 - 111s - loss: nan - accuracy: 0.5603 - val_loss: nan - val_accuracy: 0.5633 - 111s/epoch - 178ms/step
# Epoch 23/30
# 625/625 - 109s - loss: nan - accuracy: 0.5603 - val_loss: nan - val_accuracy: 0.5633 - 109s/epoch - 174ms/step
# Epoch 24/30
# 625/625 - 106s - loss: nan - accuracy: 0.5603 - val_loss: nan - val_accuracy: 0.5633 - 106s/epoch - 170ms/step
# Epoch 25/30
# 625/625 - 109s - loss: nan - accuracy: 0.5603 - val_loss: nan - val_accuracy: 0.5633 - 109s/epoch - 175ms/step
# Epoch 26/30
# 625/625 - 111s - loss: nan - accuracy: 0.5603 - val_loss: nan - val_accuracy: 0.5633 - 111s/epoch - 178ms/step
# Epoch 27/30
# 625/625 - 110s - loss: nan - accuracy: 0.5603 - val_loss: nan - val_accuracy: 0.5633 - 110s/epoch - 176ms/step
# Epoch 28/30
# 625/625 - 108s - loss: nan - accuracy: 0.5603 - val_loss: nan - val_accuracy: 0.5633 - 108s/epoch - 173ms/step
# Epoch 29/30
# 625/625 - 107s - loss: nan - accuracy: 0.5603 - val_loss: nan - val_accuracy: 0.5633 - 107s/epoch - 172ms/step
# Epoch 30/30
# 625/625 - 111s - loss: nan - accuracy: 0.5603 - val_loss: nan - val_accuracy: 0.5633 - 111s/epoch - 178ms/step
# Epoch 1/30
# 625/625 - 113s - loss: nan - accuracy: 0.5603 - val_loss: nan - val_accuracy: 0.5633 - 113s/epoch - 180ms/step
# Epoch 2/30
# 625/625 - 114s - loss: nan - accuracy: 0.5603 - val_loss: nan - val_accuracy: 0.5633 - 114s/epoch - 183ms/step
# Epoch 3/30
# 625/625 - 112s - loss: nan - accuracy: 0.5603 - val_loss: nan - val_accuracy: 0.5633 - 112s/epoch - 180ms/step
# Epoch 4/30
# 625/625 - 113s - loss: nan - accuracy: 0.5603 - val_loss: nan - val_accuracy: 0.5633 - 113s/epoch - 181ms/step
# Epoch 5/30
# 625/625 - 113s - loss: nan - accuracy: 0.5603 - val_loss: nan - val_accuracy: 0.5633 - 113s/epoch - 180ms/step
# Epoch 6/30
# 625/625 - 112s - loss: nan - accuracy: 0.5603 - val_loss: nan - val_accuracy: 0.5633 - 112s/epoch - 178ms/step
# Epoch 7/30
# 625/625 - 115s - loss: nan - accuracy: 0.5603 - val_loss: nan - val_accuracy: 0.5633 - 115s/epoch - 184ms/step
# Epoch 8/30
# 625/625 - 116s - loss: nan - accuracy: 0.5603 - val_loss: nan - val_accuracy: 0.5633 - 116s/epoch - 185ms/step
# Epoch 9/30
# 625/625 - 116s - loss: nan - accuracy: 0.5603 - val_loss: nan - val_accuracy: 0.5633 - 116s/epoch - 186ms/step
# Epoch 10/30
# 625/625 - 115s - loss: nan - accuracy: 0.5603 - val_loss: nan - val_accuracy: 0.5633 - 115s/epoch - 184ms/step
# Epoch 11/30
# 625/625 - 114s - loss: nan - accuracy: 0.5603 - val_loss: nan - val_accuracy: 0.5633 - 114s/epoch - 183ms/step
# Epoch 12/30
# 625/625 - 115s - loss: nan - accuracy: 0.5603 - val_loss: nan - val_accuracy: 0.5633 - 115s/epoch - 184ms/step
# Epoch 13/30
# 625/625 - 116s - loss: nan - accuracy: 0.5603 - val_loss: nan - val_accuracy: 0.5633 - 116s/epoch - 186ms/step
# Epoch 14/30
# 625/625 - 115s - loss: nan - accuracy: 0.5603 - val_loss: nan - val_accuracy: 0.5633 - 115s/epoch - 184ms/step
# Epoch 15/30
# 625/625 - 117s - loss: nan - accuracy: 0.5603 - val_loss: nan - val_accuracy: 0.5633 - 117s/epoch - 187ms/step
# Epoch 16/30
# 625/625 - 115s - loss: nan - accuracy: 0.5603 - val_loss: nan - val_accuracy: 0.5633 - 115s/epoch - 185ms/step
# Epoch 17/30
# 625/625 - 116s - loss: nan - accuracy: 0.5603 - val_loss: nan - val_accuracy: 0.5633 - 116s/epoch - 186ms/step
# Epoch 18/30
# 625/625 - 113s - loss: nan - accuracy: 0.5603 - val_loss: nan - val_accuracy: 0.5633 - 113s/epoch - 181ms/step
# Epoch 19/30
# 625/625 - 111s - loss: nan - accuracy: 0.5603 - val_loss: nan - val_accuracy: 0.5633 - 111s/epoch - 178ms/step
# Epoch 20/30
# 625/625 - 114s - loss: nan - accuracy: 0.5603 - val_loss: nan - val_accuracy: 0.5633 - 114s/epoch - 183ms/step
# Epoch 21/30
# 625/625 - 116s - loss: nan - accuracy: 0.5603 - val_loss: nan - val_accuracy: 0.5633 - 116s/epoch - 185ms/step
# Epoch 22/30
# 625/625 - 115s - loss: nan - accuracy: 0.5603 - val_loss: nan - val_accuracy: 0.5633 - 115s/epoch - 185ms/step
# Epoch 23/30
# 625/625 - 117s - loss: nan - accuracy: 0.5603 - val_loss: nan - val_accuracy: 0.5633 - 117s/epoch - 187ms/step
# Epoch 24/30
# 625/625 - 114s - loss: nan - accuracy: 0.5603 - val_loss: nan - val_accuracy: 0.5633 - 114s/epoch - 183ms/step
# Epoch 25/30
# 625/625 - 116s - loss: nan - accuracy: 0.5603 - val_loss: nan - val_accuracy: 0.5633 - 116s/epoch - 185ms/step
# Epoch 26/30
# 625/625 - 115s - loss: nan - accuracy: 0.5603 - val_loss: nan - val_accuracy: 0.5633 - 115s/epoch - 184ms/step
# Epoch 27/30
# 625/625 - 116s - loss: nan - accuracy: 0.5603 - val_loss: nan - val_accuracy: 0.5633 - 116s/epoch - 186ms/step
# Epoch 28/30
# 625/625 - 115s - loss: nan - accuracy: 0.5603 - val_loss: nan - val_accuracy: 0.5633 - 115s/epoch - 184ms/step
# Epoch 29/30
# 625/625 - 115s - loss: nan - accuracy: 0.5603 - val_loss: nan - val_accuracy: 0.5633 - 115s/epoch - 185ms/step
# Epoch 30/30
# 625/625 - 115s - loss: nan - accuracy: 0.5603 - val_loss: nan - val_accuracy: 0.5633 - 115s/epoch - 184ms/step
